# %% [markdown]
# # Part 1: Construct a KG from unstructured data
#
# This notebook illustrates the internal steps for the implementation of an NLP pipeline for constructing _knowledge graphs_ from unstructured data sources.
#
# Presentation for GraphGeeks.org on 2024-08-14

# %% [markdown]
# ## Set up

# %%
from IPython.display import display, HTML, Image, SVG

from collections import defaultdict
from dataclasses import dataclass
import itertools
import os
import typing
import warnings

from gliner_spacy.pipeline import GlinerSpacy
from icecream import ic
from pydantic import BaseModel
from pyinstrument import Profiler
import glirel
import matplotlib
import matplotlib.colors
import networkx as nx
import pandas as pd
import pyvis
import spacy
import transformers

# %% [markdown]
# Override specific Hugging Face error messages, since `transformers` and `tokenizers` have noisy logging.

# %%
transformers.logging.set_verbosity_error()
os.environ["TOKENIZERS_PARALLELISM"] = "0"

# %% [markdown]
# Show a watermark of the OS, hardware, language environment, and dependent library versions.

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions
# Out:
# Last updated: 2025-02-14T23:02:03.947827-08:00
#
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.32.0
#
# Compiler    : Clang 18.1.8
# OS          : Darwin
# Release     : 24.3.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 8
# Architecture: 64bit
#
# pyvis       : 0.3.2
# pydantic    : 2.10.6
# pyinstrument: 5.0.1
# spacy       : 3.8.4
# transformers: 4.48.3
# matplotlib  : 3.10.0
# IPython     : 8.32.0
# gliner_spacy: 0.0.11
# networkx    : 3.4.2
# glirel      : 1.0.1
# pandas      : 2.2.3

# %% [markdown]
# Start the stochastic stack trace profiler.

# %%
profiler: Profiler = Profiler()
profiler.start()

# %% [markdown]
# Define the model selections and parameter settings.

# %%
CHUNK_SIZE: int = 1024

GLINER_MODEL: str = "urchade/gliner_small-v2.1"

NER_LABELS: typing.List[str] = [
    "Behavior",
    "City",
    "Company",
    "Condition",
    "Conference",
    "Country",
    "Food",
    "Food Additive",
    "Hospital",
    "Organ",
    "Organization",
    "People Group",
    "Person",
    "Publication",
    "Research",
    "Science",
    "University",
]

RE_LABELS: dict = {
    "glirel_labels": {
        "no_relation": {},
        "co_founder": {"allowed_head": ["PERSON"], "allowed_tail": ["ORG"]},
        "country_of_origin": {
            "allowed_head": ["PERSON", "ORG"],
            "allowed_tail": ["LOC", "GPE"],
        },
        "parent": {"allowed_head": ["PERSON"], "allowed_tail": ["PERSON"]},
        "followed_by": {
            "allowed_head": ["PERSON", "ORG"],
            "allowed_tail": ["PERSON", "ORG"],
        },
        "spouse": {"allowed_head": ["PERSON"], "allowed_tail": ["PERSON"]},
        "child": {"allowed_head": ["PERSON"], "allowed_tail": ["PERSON"]},
        "founder": {"allowed_head": ["PERSON"], "allowed_tail": ["ORG"]},
        "headquartered_in": {
            "allowed_head": ["ORG"],
            "allowed_tail": ["LOC", "GPE", "FAC"],
        },
        "acquired_by": {"allowed_head": ["ORG"], "allowed_tail": ["ORG", "PERSON"]},
        "subsidiary_of": {"allowed_head": ["ORG"], "allowed_tail": ["ORG", "PERSON"]},
    }
}

SPACY_MODEL: str = "en_core_web_md"

STOP_WORDS: typing.Set[str] = set(
    [
        "PRON.it",
        "PRON.that",
        "PRON.they",
        "PRON.those",
        "PRON.we",
        "PRON.which",
        "PRON.who",
    ]
)

TR_ALPHA: float = 0.85
TR_LOOKBACK: int = 3

# %% [markdown]
# Load the models for `spaCy`, `GLiNER`, `GLiREL` -- this may take several minutes when run the first time.

# %%
# uv run spacy download en_core_web_md

nlp: spacy.Language = spacy.load(SPACY_MODEL)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    nlp.add_pipe(
        "gliner_spacy",
        config={
            "gliner_model": GLINER_MODEL,
            "labels": NER_LABELS,
            "chunk_size": CHUNK_SIZE,
            "style": "ent",
        },
    )

    nlp.add_pipe(
        "glirel",
        after="ner",
    )
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# gliner_config.json:   0%|          | 0.00/477 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.76k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/611M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.87G [00:00<?, ?B/s]
# glirel_config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/874M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/874M [00:00<?, ?B/s]

# %% [markdown]
# Define the global data structures -- which need to be reset for every run, not for each chunk iteration.

# %%
graph: nx.Graph = nx.Graph()
known_lemma: typing.List[str] = []

# %% [markdown]
# ## Parse one text chunk

# %% [markdown]
# Define an input text chunk.

# %%
class TextChunk(BaseModel):
    uid: int
    url: str
    text: str


SAMPLE_CHUNK: TextChunk = TextChunk(
    uid=1,
    url="https://www.theguardian.com/society/article/2024/jul/31/eating-processed-red-meat-could-increase-risk-of-dementia-study-finds",
    text="""
Eating processed red meat could be a significant risk factor for dementia, according to a large study that tracked more than 100,000 people over four decades.
Processed red meat has previously been shown to increase the risk of cancer, heart disease and type 2 diabetes. Now US researchers say they have uncovered a potential link to dementia.
The study also found that replacing processed red meat with healthier foods such as nuts, beans or tofu could help reduce the risk of dementia. The findings were presented at the Alzheimer’s Association international conference in the US.
The number of people living with dementia globally is forecast to nearly triple to 153 million by 2050, and studies looking at diet and risk of cognitive decline has become a focus of researchers.

In the latest research, experts studied the health of 130,000 nurses and other health workers working in the US. They were tracked for 43 years and provided data on their diet every 2 to 5 years.
The participants were asked how often they ate processed red meat including bacon, hotdogs, sausages, salami and other sandwich meat.
They were also asked about their consumption of nuts and legumes including peanut butter, peanuts, walnuts and other nuts, string beans, beans, peas, soy milk and tofu.

More than 11,000 cases of dementia were identified during the follow-up period.
Consuming two servings of processed red meat each week appeared to raise the risk of cognitive decline by 14% compared with those eating about three servings a month, the researchers reported.
The study also suggested that replacing one daily serving of processed red meat for a daily serving of nuts, beans or tofu every day could lower the risk of dementia by 23%.
    """.strip(),
)

chunk: TextChunk = SAMPLE_CHUNK

# %% [markdown]
# Parse the input text.

# %%
doc: spacy.tokens.doc.Doc = list(
    nlp.pipe(
        [(chunk.text, RE_LABELS)],
        as_tuples=True,
    )
)[
    0
][0]

# %% [markdown]
# Visualize the `spaCy` parse and `GLiNER` _named entity recognition_ results.

# %%
for sent in doc.sents:
    spacy.displacy.render(
        sent,
        style="ent",
        jupyter=True,
    )

    parse_svg: str = spacy.displacy.render(
        sent,
        style="dep",
        jupyter=True,
    )

    display(SVG(parse_svg))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Eating
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     processed red meat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  could be a significant risk factor for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
# , according to a large study that tracked more than 100,000 people over four decades.<br></div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="27fa17b7d4604d9c9fb7755e148732ae-0" class="displacy" width="4775" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Eating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">processed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">red</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">meat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">factor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">dementia,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">according</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">large</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">tracked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">100,000</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">four</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">decades.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27fa17b7d4604d9c9fb7755e148732ae-0-0" stroke-width="2px" d="M70,527.0 C70,177.0 915.0,177.0 915.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27fa17b7d4604d9c9fb7755e148732ae-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">csubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-27fa17b7d4604d9c9fb7755e148732ae-0-1" stroke-width="2px" d="M245,527.0 C245,352.0 555.0,352.0 555.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-27fa17b7d4604d9c9fb7755e148732ae-0-1" class="displacy-label" startOffse
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Processed red meat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  has previously been shown to increase the risk of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heart disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     type 2 diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="889d462aaeb049c6bb937ea05fd2587d-0" class="displacy" width="3375" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Processed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">red</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">meat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">previously</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">shown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">increase</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">cancer,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">heart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">disease</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">type</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">diabetes.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-889d462aaeb049c6bb937ea05fd2587d-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-889d462aaeb049c6bb937ea05fd2587d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-889d462aaeb049c6bb937ea05fd2587d-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-889d462aaeb049c6bb937ea05fd2587d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-889d462aaeb049c6bb937ea05fd2587d-0-2" stroke-width="2px" d="M420,352.0 C420,2.0 1100.0,2.0 1100.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-889d462aaeb049c6bb937ea05fd2587d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-889d462aaeb049c6bb937ea05fd2587d-0-3" stroke-width="2px" d="M595,352.0 C595,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-889d462aaeb049c6bb937ea05fd2587d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-889d462aaeb049c6bb937ea05fd2587d-0-4" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-889d462aaeb049c6bb937ea05fd2587d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc"
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Now
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Country</span>
# </mark>
#  researchers say they have uncovered a potential link to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
# .<br></div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f7c1499426b4d0cba597f7cf6878eca-0" class="displacy" width="2325" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">say</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">uncovered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">potential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">link</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">dementia.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-3" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-5" stroke-width="2px" d="M595,352.0 C595,89.5 1095.0,89.5 1095.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,354.0 L1103.0,342.0 1087.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-6" stroke-width="2px" d="M1295,352.0 C1295,177.0 1615.0,177.0 1615.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5f7c1499426b4d0cba597f7cf6878eca-0-7" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5f7c1499426b4d0cba597f7cf6878eca-0-7" class="displa
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The study also found that replacing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     processed red meat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  with healthier foods such as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nuts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     beans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tofu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  could help reduce the risk of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6fedace36815441d9a1efe5860326071-0" class="displacy" width="4425" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">found</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">replacing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">processed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">red</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">meat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">healthier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">foods</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">such</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">nuts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">beans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">tofu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">help</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">reduce</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">dementia.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6fedace36815441d9a1efe5860326071-0-0" stroke-width="2px" d="M70,614.5 C70,527.0 195.0,527.0 195.0,614.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6fedace36815441d9a1efe5860326071-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,616.5 L62,604.5 78,604.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6fedace36815441d9a1efe5860326071-0-1" stroke-width="2px" d="M245,614.5 C245,439.5 550.0,439.5 550.0,614.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6fedace36815441d9a1efe5860326071-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,616.5 L237,604.5 253,604.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6fedace36815441d9a1efe5860326071-0-2" stroke-width="2px" d="M420,614.5 C420,527.0 545.0,527.0 545.0,614.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The findings were presented at the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alzheimer’s Association international conference
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Conference</span>
# </mark>
#  in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Country</span>
# </mark>
# .<br></div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="783b1be59f90477c92ca79da13f2f403-0" class="displacy" width="2675" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">findings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">presented</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Alzheimer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Association</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">international</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">conference</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">US.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-0" stroke-width="2px" d="M70,527.0 C70,439.5 200.0,439.5 200.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-1" stroke-width="2px" d="M245,527.0 C245,352.0 555.0,352.0 555.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-2" stroke-width="2px" d="M420,527.0 C420,439.5 550.0,439.5 550.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,529.0 L412,517.0 428,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-3" stroke-width="2px" d="M595,527.0 C595,439.5 725.0,439.5 725.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M725.0,529.0 L733.0,517.0 717.0,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-4" stroke-width="2px" d="M945,527.0 C945,177.0 1790.0,177.0 1790.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,529.0 L937,517.0 953,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-5" stroke-width="2px" d="M1120,527.0 C1120,264.5 1785.0,264.5 1785.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,529.0 L1112,517.0 1128,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-783b1be59f90477c92ca79da13f2f403-0-6" stroke-width="2px" d="M1120,527.0 C1120,439.5 1250.0,439.5 1250.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-783b1be59f90477c92ca79da13f2f403-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="mid
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The number of people living with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
#  globally is forecast to nearly triple to 153 million by 2050, and studies looking at diet and risk of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cognitive decline
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
#  has become a focus of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     researchers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">People Group</span>
# </mark>
# .<br><br></div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ce3bf7bf655742ed82c0434070f36195-0" class="displacy" width="6175" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">number</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">people</tspan>
# ...
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">week</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">appeared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">raise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">cognitive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">decline</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">14%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">compared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">those</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">eating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">servings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">month,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">researchers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">reported.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curr
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Research</span>
# </mark>
#  also suggested that replacing one daily serving of processed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red meat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  for a daily serving of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nuts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     beans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tofu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Food</span>
# </mark>
#  every day could lower the risk of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Condition</span>
# </mark>
#  by 23%.</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="08907fe6886445a8ae14024539d36e5a-0" class="displacy" width="5650" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">suggested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">replacing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">daily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">serving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">processed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">red</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">meat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">daily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">serving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">nuts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">beans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">tofu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">day</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">lower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">dementia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP<

# %% [markdown]
# ## Layer 1: construct a lexical graph

# %% [markdown]
# Scan the document tokens to add lemmas to the _textgraph_.

# %%
for sent in doc.sents:
    node_seq: typing.List[int] = []
    ic(sent)

    for tok in sent:
        text: str = tok.text.strip()

        if tok.pos_ in ["NOUN", "PROPN"]:
            key: str = tok.pos_ + "." + tok.lemma_.strip().lower()
            print(tok.i, key, tok.text.strip())

            if key not in known_lemma:
                # create a new node
                known_lemma.append(key)
                node_id: int = known_lemma.index(key)
                node_seq.append(node_id)

                graph.add_node(
                    node_id,
                    key=key,
                    kind="Lemma",
                    pos=tok.pos_,
                    text=text,
                    chunk=chunk.uid,
                    count=1,
                )
            else:
                # link to an existing node, adding weight
                node_id = known_lemma.index(key)
                node_seq.append(node_id)

                node: dict = graph.nodes[node_id]
                node["count"] += 1

    # create the textrank edges
    ic(node_seq)

    for hop in range(TR_LOOKBACK):
        for node_id, node in enumerate(node_seq[: -1 - hop]):
            neighbor: int = node_seq[hop + node_id + 1]
            graph.add_edge(
                node,
                neighbor,
                rel="FOLLOWS_LEXICALLY",
            )
# Out:
# ic| sent: Eating processed red meat could be a significant risk factor for dementia, according to a large study that tracked more than 100,000 people over four decades.
# ic| node_seq: [0, 1, 2, 3, 4, 5, 6]
# ic| sent: Processed red meat has previously been shown to increase the risk of cancer, heart disease and type 2 diabetes.
# ic| node_seq: [0, 1, 7, 8, 9, 10, 11]
# ic| sent: Now US researchers say they have uncovered a potential link to dementia.
# ic| node_seq: [12, 13, 14, 3]
# ic| sent: The study also found that replacing processed red meat with healthier foods such as nuts, beans or tofu could help reduce the risk of dementia.
# ic| node_seq: [4, 0, 15, 16, 17, 18, 1, 3]
# ic| sent: The findings were presented at the Alzheimer’s Association international conference in the US.
# ic| node_seq: [19, 20, 21, 22, 12]
# ic| sent: The number of people living with dementia globally is forecast to nearly triple
# 3 NOUN.meat meat
# 8 NOUN.risk risk
# 9 NOUN.factor factor
# 11 NOUN.dementia dementia
# 17 NOUN.study study
# 23 NOUN.people people
# 26 NOUN.decade decades
# 31 NOUN.meat meat
# 39 NOUN.risk risk
# 41 NOUN.cancer cancer
# 43 NOUN.heart heart
# 44 NOUN.disease disease
# 46 NOUN.type type
# 48 NOUN.diabetes diabetes
# 51 PROPN.us US
# 52 NOUN.researcher researchers
# 59 NOUN.link link
# 61 NOUN.dementia dementia
# 65 NOUN.study study
# 72 NOUN.meat meat
# 75 NOUN.food foods
# 78 NOUN.nut nuts
# 80 NOUN.bean beans
# 82 NOUN.tofu tofu
# 87 NOUN.risk risk
# 89 NOUN.dementia dementia
# 92 NOUN.finding findings
# 97 PROPN.alzheimer Alzheimer
# 99 PROPN.association Association
# 101 NOUN.conference conference
# 104 PROPN.us US
#  to 153 million by 2050, and studies looking at diet and risk of cognitive decline has become a focus of researchers.
#
# ic| node_seq: [23, 5, 3, 4, 24, 1, 25, 26, 13]
# ic| sent: In the latest research, experts studied the health of 130,000 nurses and other health workers working in the US.
# ic| node_seq: [27, 28, 29, 30, 29, 31, 12]
# ic| sent: They were tracked for 43 years and provided data on their diet every 2 to 5 years.
# ic| node_seq: [32, 33, 24, 32]
# ic| sent: The participants were asked how often they ate processed red meat including bacon, hotdogs, sausages, salami and other sandwich meat.
# ic| node_seq: [34, 0, 35, 36, 37, 38, 39, 0]
# ic| sent: They were also asked about their consumption of nuts and legumes including peanut butter, peanuts, walnuts and other nuts, string beans, beans, peas, soy milk and tofu.
#
# ic| node_seq: [40, 16, 41, 42, 43, 42, 44, 16, 45, 17, 17, 46, 47,
# 108 NOUN.number number
# 110 NOUN.people people
# 113 NOUN.dementia dementia
# 127 NOUN.study studies
# 130 NOUN.diet diet
# 132 NOUN.risk risk
# 135 NOUN.decline decline
# 139 NOUN.focus focus
# 141 NOUN.researcher researchers
# 147 NOUN.research research
# 149 NOUN.expert experts
# 152 NOUN.health health
# 155 NOUN.nurse nurses
# 158 NOUN.health health
# 159 NOUN.worker workers
# 163 PROPN.us US
# 170 NOUN.year years
# 173 NOUN.datum data
# 176 NOUN.diet diet
# 181 NOUN.year years
# 185 NOUN.participant participants
# 194 NOUN.meat meat
# 196 NOUN.bacon bacon
# 198 NOUN.hotdog hotdogs
# 200 NOUN.sausage sausages
# 202 NOUN.salami salami
# 205 NOUN.sandwich sandwich
# 206 NOUN.meat meat
# 215 NOUN.consumption consumption
# 217 NOUN.nut nuts
# 219 NOUN.legume legumes
# 221 NOUN.peanut peanut
# 222 NOUN.butter butter
# 224 NOUN.peanut peanuts
# 226 NOUN.walnut walnuts
# 229 NOUN.nut nuts
# 231 NOUN.string string
# 232 NOUN.bean beans
# 234 NOUN.bean beans
# 236 NOUN.pea peas
# 238 NOUN.soy soy
# 239 NOUN.milk milk
# 241 NOUN.tofu tofu
#  48, 18]
# ic| sent: More than 11,000 cases of dementia were identified during the follow-up period.
# ic| node_seq: [49, 3, 50, 51, 52]
# ic| sent: Consuming two servings of processed red meat each week appeared to raise the risk of cognitive decline by 14% compared with those eating about three servings a month, the researchers reported.
# ic| node_seq: [53, 0, 54, 1, 25, 55, 53, 56, 13]
# ic| sent: The study also suggested that replacing one daily serving of processed red meat for a daily serving of nuts, beans or tofu every day could lower the risk of dementia by 23%.
# ic| node_seq: [4, 0, 53, 16, 17, 18, 57, 1, 3, 55]
# 247 NOUN.case cases
# 249 NOUN.dementia dementia
# 254 NOUN.follow follow
# 256 NOUN.up up
# 257 NOUN.period period
# 262 NOUN.serving servings
# 266 NOUN.meat meat
# 268 NOUN.week week
# 273 NOUN.risk risk
# 276 NOUN.decline decline
# 279 NOUN.% %
# 286 NOUN.serving servings
# 288 NOUN.month month
# 291 NOUN.researcher researchers
# 296 NOUN.study study
# 307 NOUN.meat meat
# 311 NOUN.serving serving
# 313 NOUN.nut nuts
# 315 NOUN.bean beans
# 317 NOUN.tofu tofu
# 319 NOUN.day day
# 323 NOUN.risk risk
# 325 NOUN.dementia dementia
# 328 NOUN.% %

# %% [markdown]
# Keep track of the sentence numbers, which we'll use later for entity co-occurrence links.

# %%
sent_map: typing.Dict[spacy.tokens.span.Span, int] = {}

for sent_id, sent in enumerate(doc.sents):
    sent_map[sent] = sent_id

# %% [markdown]
# ## Layer 2: overlay entities onto the graph

# %% [markdown]
# Classify spans as potential entities.
#
# Note that if we'd run [_entity resolution_](https://neo4j.com/developer-blog/entity-resolved-knowledge-graphs/) previously from _structured_ or _semi-structured_ data sources to generate a "backbone" for the knowledge graph, then we use the contextualized _surface forms_ from that phase to perform _entity linking_ on the entities extracted here from _unstructured_ data.

# %%
@dataclass(order=False, frozen=False)
class Entity:
    loc: typing.Tuple[int]
    key: str
    text: str
    label: str
    chunk_id: int
    sent_id: int
    span: spacy.tokens.span.Span
    node: typing.Optional[int] = None


span_decoder: typing.Dict[tuple, Entity] = {}


def make_entity(
    span: spacy.tokens.span.Span,
    chunk: TextChunk,
) -> Entity:
    """
    Instantiate one `Entity` dataclass object, adding it to the working "vocabulary".
    """
    key: str = " ".join([tok.pos_ + "." + tok.lemma_.strip().lower() for tok in span])

    ent: Entity = Entity(
        (
            span.start,
            span.end,
        ),
        key,
        span.text,
        span.label_,
        chunk.uid,
        sent_map[span.sent],
        span,
    )

    if ent.loc not in span_decoder:
        span_decoder[ent.loc] = ent
        ic(ent)

    return ent

# %%
for span in doc.ents:
    make_entity(span, chunk)

for span in doc.noun_chunks:
    make_entity(span, chunk)
# Out:
# ic| ent: Entity(loc=(1, 4),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(11, 12),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(29, 32),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='Processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=Processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(41, 42),
#                 key='NOUN.cancer',
#                 text='cancer',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=cancer,
#                 node=None)
# ic| ent: Entity(loc=(43, 45),
#                 key='NOUN.heart NOUN.disease',
#                 text='heart disease',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=heart disease,
#                 node=None)
# ic| ent: Entity(loc=(46, 49),
#                 key='NOUN.type NUM.2 NOUN.diabetes',
#                 text='type 2 diabetes',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=type 2 diabetes,
#                 node=None)
# ic| ent: Entity(loc=(51, 52),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=US,
#                 node=None)
# ic| ent: Entity(loc=(61, 62),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(70, 73),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(78, 79),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=nuts,
#                 node=None)
# ic| ent: Entity(loc=(80, 81),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=beans,
#                 node=None)
# ic| ent: Entity(loc=(82, 83),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=tofu,
#                 node=None)
# ic| ent: Entity(loc=(89, 90),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(97, 102),
#                 key='PROPN.alzheimer PART.’s PROPN.association ADJ.international '
#                     'NOUN.conference',
#                 text='Alzheimer’s Association international conference',
#                 label='Conference',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=Alzheimer’s Association international conference,
#                 node=None)
# ic| ent: Entity(loc=(104, 105),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=US,
#                 node=None)
# ic| ent: Entity(loc=(113, 114),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(134, 136),
#                 key='ADJ.cognitive NOUN.decline',
#                 text='cognitive decline',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=cognitive decline,
#                 node=None)
# ic| ent: Entity(loc=(141, 142),
#                 key='NOUN.researcher',
#                 text='researchers',
#                 label='People Group',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=researchers,
#                 node=None)
# ic| ent: Entity(loc=(163, 164),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=US,
#                 node=None)
# ic| ent: Entity(loc=(193, 195),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=red meat,
#                 node=None)
# ic| ent: Entity(loc=(196, 197),
#                 key='NOUN.bacon',
#                 text='bacon',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=bacon,
#                 node=None)
# ic| ent: Entity(loc=(198, 199),
#                 key='NOUN.hotdog',
#                 text='hotdogs',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=hotdogs,
#                 node=None)
# ic| ent: Entity(loc=(200, 201),
#                 key='NOUN.sausage',
#                 text='sausages',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=sausages,
#                 node=None)
# ic| ent: Entity(loc=(202, 203),
#                 key='NOUN.salami',
#                 text='salami',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=salami,
#                 node=None)
# ic| ent: Entity(loc=(221, 223),
#                 key='NOUN.peanut NOUN.butter',
#                 text='peanut butter',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peanut butter,
#                 node=None)
# ic| ent: Entity(loc=(224, 225),
#                 key='NOUN.peanut',
#                 text='peanuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peanuts,
#                 node=None)
# ic| ent: Entity(loc=(226, 227),
#                 key='NOUN.walnut',
#                 text='walnuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=walnuts,
#                 node=None)
# ic| ent: Entity(loc=(229, 230),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=nuts,
#                 node=None)
# ic| ent: Entity(loc=(231, 233),
#                 key='NOUN.string NOUN.bean',
#                 text='string beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=string beans,
#                 node=None)
# ic| ent: Entity(loc=(234, 235),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=beans,
#                 node=None)
# ic| ent: Entity(loc=(236, 237),
#                 key='NOUN.pea',
#                 text='peas',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peas,
#                 node=None)
# ic| ent: Entity(loc=(238, 240),
#                 key='NOUN.soy NOUN.milk',
#                 text='soy milk',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=soy milk,
#                 node=None)
# ic| ent: Entity(loc=(241, 242),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=tofu,
#                 node=None)
# ic| ent: Entity(loc=(249, 250),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(265, 267),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=red meat,
#                 node=None)
# ic| ent: Entity(loc=(275, 277),
#                 key='ADJ.cognitive NOUN.decline',
#                 text='cognitive decline',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=cognitive decline,
#                 node=None)
# ic| ent: Entity(loc=(296, 297),
#                 key='NOUN.study',
#                 text='study',
#                 label='Research',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=study,
#                 node=None)
# ic| ent: Entity(loc=(306, 308),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=red meat,
#                 node=None)
# ic| ent: Entity(loc=(313, 314),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=nuts,
#                 node=None)
# ic| ent: Entity(loc=(315, 316),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=beans,
#                 node=None)
# ic| ent: Entity(loc=(317, 318),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=tofu,
#                 node=None)
# ic| ent: Entity(loc=(325, 326),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=dementia,
#                 node=None)
# ic| ent: Entity(loc=(6, 10),
#                 key='DET.a ADJ.significant NOUN.risk NOUN.factor',
#                 text='a significant risk factor',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=a significant risk factor,
#                 node=None)
# ic| ent: Entity(loc=(15, 18),
#                 key='DET.a ADJ.large NOUN.study',
#                 text='a large study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=a large study,
#                 node=None)
# ic| ent: Entity(loc=(18, 19),
#                 key='PRON.that',
#                 text='that',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=that,
#                 node=None)
# ic| ent: Entity(loc=(20, 24),
#                 key='ADJ.more ADP.than NUM.100,000 NOUN.people',
#                 text='more than 100,000 people',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=more than 100,000 people,
#                 node=None)
# ic| ent: Entity(loc=(25, 27),
#                 key='NUM.four NOUN.decade',
#                 text='four decades',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=four decades,
#                 node=None)
# ic| ent: Entity(loc=(38, 40),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=the risk,
#                 node=None)
# ic| ent: Entity(loc=(51, 53),
#                 key='PROPN.us NOUN.researcher',
#                 text='US researchers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=US researchers,
#                 node=None)
# ic| ent: Entity(loc=(54, 55),
#                 key='PRON.they',
#                 text='they',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=they,
#                 node=None)
# ic| ent: Entity(loc=(57, 60),
#                 key='DET.a ADJ.potential NOUN.link',
#                 text='a potential link',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=a potential link,
#                 node=None)
# ic| ent: Entity(loc=(64, 66),
#                 key='DET.the NOUN.study',
#                 text='The study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=The study,
#                 node=None)
# ic| ent: Entity(loc=(74, 76),
#                 key='ADJ.healthy NOUN.food',
#                 text='healthier foods',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=healthier foods,
#                 node=None)
# ic| ent: Entity(loc=(86, 88),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=the risk,
#                 node=None)
# ic| ent: Entity(loc=(91, 93),
#                 key='DET.the NOUN.finding',
#                 text='The findings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=The findings,
#                 node=None)
# ic| ent: Entity(loc=(96, 102),
#                 key='DET.the PROPN.alzheimer PART.’s PROPN.association '
#                     'ADJ.international NOUN.conference',
#                 text='the Alzheimer’s Association international conference',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=the Alzheimer’s Association international conference,
#                 node=None)
# ic| ent: Entity(loc=(103, 105),
#                 key='DET.the PROPN.us',
#                 text='the US',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=the US,
#                 node=None)
# ic| ent: Entity(loc=(107, 109),
#                 key='DET.the NOUN.number',
#                 text='The number',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=The number,
#                 node=None)
# ic| ent: Entity(loc=(110, 111),
#                 key='NOUN.people',
#                 text='people',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=people,
#                 node=None)
# ic| ent: Entity(loc=(127, 128),
#                 key='NOUN.study',
#                 text='studies',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=studies,
#                 node=None)
# ic| ent: Entity(loc=(130, 131),
#                 key='NOUN.diet',
#                 text='diet',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=diet,
#                 node=None)
# ic| ent: Entity(loc=(132, 133),
#                 key='NOUN.risk',
#                 text='risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=risk,
#                 node=None)
# ic| ent: Entity(loc=(138, 140),
#                 key='DET.a NOUN.focus',
#                 text='a focus',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=a focus,
#                 node=None)
# ic| ent: Entity(loc=(145, 148),
#                 key='DET.the ADJ.late NOUN.research',
#                 text='the latest research',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the latest research,
#                 node=None)
# ic| ent: Entity(loc=(149, 150),
#                 key='NOUN.expert',
#                 text='experts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=experts,
#                 node=None)
# ic| ent: Entity(loc=(151, 153),
#                 key='DET.the NOUN.health',
#                 text='the health',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the health,
#                 node=None)
# ic| ent: Entity(loc=(154, 156),
#                 key='NUM.130,000 NOUN.nurse',
#                 text='130,000 nurses',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=130,000 nurses,
#                 node=None)
# ic| ent: Entity(loc=(157, 160),
#                 key='ADJ.other NOUN.health NOUN.worker',
#                 text='other health workers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=other health workers,
#                 node=None)
# ic| ent: Entity(loc=(162, 164),
#                 key='DET.the PROPN.us',
#                 text='the US',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the US,
#                 node=None)
# ic| ent: Entity(loc=(165, 166),
#                 key='PRON.they',
#                 text='They',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=They,
#                 node=None)
# ic| ent: Entity(loc=(169, 171),
#                 key='NUM.43 NOUN.year',
#                 text='43 years',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=43 years,
#                 node=None)
# ic| ent: Entity(loc=(173, 174),
#                 key='NOUN.datum',
#                 text='data',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=data,
#                 node=None)
# ic| ent: Entity(loc=(175, 177),
#                 key='PRON.their NOUN.diet',
#                 text='their diet',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=their diet,
#                 node=None)
# ic| ent: Entity(loc=(184, 186),
#                 key='DET.the NOUN.participant',
#                 text='The participants',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=The participants,
#                 node=None)
# ic| ent: Entity(loc=(190, 191),
#                 key='PRON.they',
#                 text='they',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=they,
#                 node=None)
# ic| ent: Entity(loc=(192, 195),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(204, 207),
#                 key='ADJ.other NOUN.sandwich NOUN.meat',
#                 text='other sandwich meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=other sandwich meat,
#                 node=None)
# ic| ent: Entity(loc=(209, 210),
#                 key='PRON.they',
#                 text='They',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=They,
#                 node=None)
# ic| ent: Entity(loc=(214, 216),
#                 key='PRON.their NOUN.consumption',
#                 text='their consumption',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=their consumption,
#                 node=None)
# ic| ent: Entity(loc=(217, 218),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=nuts,
#                 node=None)
# ic| ent: Entity(loc=(219, 220),
#                 key='NOUN.legume',
#                 text='legumes',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=legumes,
#                 node=None)
# ic| ent: Entity(loc=(228, 230),
#                 key='ADJ.other NOUN.nut',
#                 text='other nuts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=other nuts,
#                 node=None)
# ic| ent: Entity(loc=(244, 248),
#                 key='ADJ.more ADP.than NUM.11,000 NOUN.case',
#                 text='More than 11,000 cases',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=More than 11,000 cases,
#                 node=None)
# ic| ent: Entity(loc=(253, 258),
#                 key='DET.the NOUN.follow PUNCT.- NOUN.up NOUN.period',
#                 text='the follow-up period',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=the follow-up period,
#                 node=None)
# ic| ent: Entity(loc=(261, 263),
#                 key='NUM.two NOUN.serving',
#                 text='two servings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=two servings,
#                 node=None)
# ic| ent: Entity(loc=(264, 267),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(272, 274),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=the risk,
#                 node=None)
# ic| ent: Entity(loc=(278, 280),
#                 key='NUM.14 NOUN.%',
#                 text='14%',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=14%,
#                 node=None)
# ic| ent: Entity(loc=(282, 283),
#                 key='PRON.those',
#                 text='those',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=those,
#                 node=None)
# ic| ent: Entity(loc=(284, 287),
#                 key='ADV.about NUM.three NOUN.serving',
#                 text='about three servings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=about three servings,
#                 node=None)
# ic| ent: Entity(loc=(290, 292),
#                 key='DET.the NOUN.researcher',
#                 text='the researchers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=the researchers,
#                 node=None)
# ic| ent: Entity(loc=(295, 297),
#                 key='DET.the NOUN.study',
#                 text='The study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=The study,
#                 node=None)
# ic| ent: Entity(loc=(305, 308),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=processed red meat,
#                 node=None)
# ic| ent: Entity(loc=(309, 312),
#                 key='DET.a ADJ.daily NOUN.serving',
#                 text='a daily serving',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=a daily serving,
#                 node=None)
# ic| ent: Entity(loc=(322, 324),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=the risk,
#                 node=None)
# ic| ent: Entity(loc=(327, 329),
#                 key='NUM.23 NOUN.%',
#                 text='23%',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=23%,
#                 node=None)

# %% [markdown]
# Overlay the inferred entity spans atop the base layer constructed by _textgraph_ analysis of the `spaCy` parse trees.

# %%
def extract_entity(
    ent: Entity,
) -> None:
    """
    Link one `Entity` into the existing graph.
    """
    if ent.key not in known_lemma:
        # add a new Entity node to the graph and link to its component Lemma nodes
        known_lemma.append(ent.key)
        node_id: int = known_lemma.index(ent.key)

        graph.add_node(
            node_id,
            key=ent.key,
            kind="Entity",
            label=ent.label,
            pos="NP",
            text=ent.text,
            chunk=ent.chunk_id,
            count=1,
        )

        for tok in ent.span:
            tok_key: str = tok.pos_ + "." + tok.lemma_.strip().lower()

            if tok_key in known_lemma:
                tok_idx: int = known_lemma.index(tok_key)

                graph.add_edge(
                    node_id,
                    tok_idx,
                    rel="COMPOUND_ELEMENT_OF",
                )
    else:
        node_id: int = known_lemma.index(ent.key)
        node: dict = graph.nodes[node_id]
        # promote to an Entity, in case the node had been a Lemma
        node["kind"] = "Entity"
        node["chunk"] = ent.chunk_id
        node["count"] += 1

        # select the more specific label
        if "label" not in node or node["label"] == "NP":
            node["label"] = ent.label

    ent.node = node_id

# %%
for ent in span_decoder.values():
    if ent.key not in STOP_WORDS:
        extract_entity(ent)
        ic(ent)
# Out:
# ic| ent: Entity(loc=(1, 4),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(11, 12),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(29, 32),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='Processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=Processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(41, 42),
#                 key='NOUN.cancer',
#                 text='cancer',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=cancer,
#                 node=7)
# ic| ent: Entity(loc=(43, 45),
#                 key='NOUN.heart NOUN.disease',
#                 text='heart disease',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=heart disease,
#                 node=59)
# ic| ent: Entity(loc=(46, 49),
#                 key='NOUN.type NUM.2 NOUN.diabetes',
#                 text='type 2 diabetes',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=type 2 diabetes,
#                 node=60)
# ic| ent: Entity(loc=(51, 52),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=US,
#                 node=12)
# ic| ent: Entity(loc=(61, 62),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(70, 73),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(78, 79),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=nuts,
#                 node=16)
# ic| ent: Entity(loc=(80, 81),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=beans,
#                 node=17)
# ic| ent: Entity(loc=(82, 83),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=tofu,
#                 node=18)
# ic| ent: Entity(loc=(89, 90),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(97, 102),
#                 key='PROPN.alzheimer PART.’s PROPN.association ADJ.international '
#                     'NOUN.conference',
#                 text='Alzheimer’s Association international conference',
#                 label='Conference',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=Alzheimer’s Association international conference,
#                 node=61)
# ic| ent: Entity(loc=(104, 105),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=US,
#                 node=12)
# ic| ent: Entity(loc=(113, 114),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(134, 136),
#                 key='ADJ.cognitive NOUN.decline',
#                 text='cognitive decline',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=cognitive decline,
#                 node=62)
# ic| ent: Entity(loc=(141, 142),
#                 key='NOUN.researcher',
#                 text='researchers',
#                 label='People Group',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=researchers,
#                 node=13)
# ic| ent: Entity(loc=(163, 164),
#                 key='PROPN.us',
#                 text='US',
#                 label='Country',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=US,
#                 node=12)
# ic| ent: Entity(loc=(193, 195),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=red meat,
#                 node=63)
# ic| ent: Entity(loc=(196, 197),
#                 key='NOUN.bacon',
#                 text='bacon',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=bacon,
#                 node=35)
# ic| ent: Entity(loc=(198, 199),
#                 key='NOUN.hotdog',
#                 text='hotdogs',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=hotdogs,
#                 node=36)
# ic| ent: Entity(loc=(200, 201),
#                 key='NOUN.sausage',
#                 text='sausages',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=sausages,
#                 node=37)
# ic| ent: Entity(loc=(202, 203),
#                 key='NOUN.salami',
#                 text='salami',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=salami,
#                 node=38)
# ic| ent: Entity(loc=(221, 223),
#                 key='NOUN.peanut NOUN.butter',
#                 text='peanut butter',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peanut butter,
#                 node=64)
# ic| ent: Entity(loc=(224, 225),
#                 key='NOUN.peanut',
#                 text='peanuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peanuts,
#                 node=42)
# ic| ent: Entity(loc=(226, 227),
#                 key='NOUN.walnut',
#                 text='walnuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=walnuts,
#                 node=44)
# ic| ent: Entity(loc=(229, 230),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=nuts,
#                 node=16)
# ic| ent: Entity(loc=(231, 233),
#                 key='NOUN.string NOUN.bean',
#                 text='string beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=string beans,
#                 node=65)
# ic| ent: Entity(loc=(234, 235),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=beans,
#                 node=17)
# ic| ent: Entity(loc=(236, 237),
#                 key='NOUN.pea',
#                 text='peas',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=peas,
#                 node=46)
# ic| ent: Entity(loc=(238, 240),
#                 key='NOUN.soy NOUN.milk',
#                 text='soy milk',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=soy milk,
#                 node=66)
# ic| ent: Entity(loc=(241, 242),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=tofu,
#                 node=18)
# ic| ent: Entity(loc=(249, 250),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(265, 267),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=red meat,
#                 node=63)
# ic| ent: Entity(loc=(275, 277),
#                 key='ADJ.cognitive NOUN.decline',
#                 text='cognitive decline',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=cognitive decline,
#                 node=62)
# ic| ent: Entity(loc=(296, 297),
#                 key='NOUN.study',
#                 text='study',
#                 label='Research',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=study,
#                 node=4)
# ic| ent: Entity(loc=(306, 308),
#                 key='ADJ.red NOUN.meat',
#                 text='red meat',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=red meat,
#                 node=63)
# ic| ent: Entity(loc=(313, 314),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=nuts,
#                 node=16)
# ic| ent: Entity(loc=(315, 316),
#                 key='NOUN.bean',
#                 text='beans',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=beans,
#                 node=17)
# ic| ent: Entity(loc=(317, 318),
#                 key='NOUN.tofu',
#                 text='tofu',
#                 label='Food',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=tofu,
#                 node=18)
# ic| ent: Entity(loc=(325, 326),
#                 key='NOUN.dementia',
#                 text='dementia',
#                 label='Condition',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=dementia,
#                 node=3)
# ic| ent: Entity(loc=(6, 10),
#                 key='DET.a ADJ.significant NOUN.risk NOUN.factor',
#                 text='a significant risk factor',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=a significant risk factor,
#                 node=67)
# ic| ent: Entity(loc=(15, 18),
#                 key='DET.a ADJ.large NOUN.study',
#                 text='a large study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=a large study,
#                 node=68)
# ic| ent: Entity(loc=(20, 24),
#                 key='ADJ.more ADP.than NUM.100,000 NOUN.people',
#                 text='more than 100,000 people',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=more than 100,000 people,
#                 node=69)
# ic| ent: Entity(loc=(25, 27),
#                 key='NUM.four NOUN.decade',
#                 text='four decades',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=0,
#                 span=four decades,
#                 node=70)
# ic| ent: Entity(loc=(38, 40),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=1,
#                 span=the risk,
#                 node=71)
# ic| ent: Entity(loc=(51, 53),
#                 key='PROPN.us NOUN.researcher',
#                 text='US researchers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=US researchers,
#                 node=72)
# ic| ent: Entity(loc=(57, 60),
#                 key='DET.a ADJ.potential NOUN.link',
#                 text='a potential link',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=2,
#                 span=a potential link,
#                 node=73)
# ic| ent: Entity(loc=(64, 66),
#                 key='DET.the NOUN.study',
#                 text='The study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=The study,
#                 node=74)
# ic| ent: Entity(loc=(74, 76),
#                 key='ADJ.healthy NOUN.food',
#                 text='healthier foods',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=healthier foods,
#                 node=75)
# ic| ent: Entity(loc=(86, 88),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=3,
#                 span=the risk,
#                 node=71)
# ic| ent: Entity(loc=(91, 93),
#                 key='DET.the NOUN.finding',
#                 text='The findings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=The findings,
#                 node=76)
# ic| ent: Entity(loc=(96, 102),
#                 key='DET.the PROPN.alzheimer PART.’s PROPN.association '
#                     'ADJ.international NOUN.conference',
#                 text='the Alzheimer’s Association international conference',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=the Alzheimer’s Association international conference,
#                 node=77)
# ic| ent: Entity(loc=(103, 105),
#                 key='DET.the PROPN.us',
#                 text='the US',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=4,
#                 span=the US,
#                 node=78)
# ic| ent: Entity(loc=(107, 109),
#                 key='DET.the NOUN.number',
#                 text='The number',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=The number,
#                 node=79)
# ic| ent: Entity(loc=(110, 111),
#                 key='NOUN.people',
#                 text='people',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=people,
#                 node=5)
# ic| ent: Entity(loc=(127, 128),
#                 key='NOUN.study',
#                 text='studies',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=studies,
#                 node=4)
# ic| ent: Entity(loc=(130, 131),
#                 key='NOUN.diet',
#                 text='diet',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=diet,
#                 node=24)
# ic| ent: Entity(loc=(132, 133),
#                 key='NOUN.risk',
#                 text='risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=risk,
#                 node=1)
# ic| ent: Entity(loc=(138, 140),
#                 key='DET.a NOUN.focus',
#                 text='a focus',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=5,
#                 span=a focus,
#                 node=80)
# ic| ent: Entity(loc=(145, 148),
#                 key='DET.the ADJ.late NOUN.research',
#                 text='the latest research',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the latest research,
#                 node=81)
# ic| ent: Entity(loc=(149, 150),
#                 key='NOUN.expert',
#                 text='experts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=experts,
#                 node=28)
# ic| ent: Entity(loc=(151, 153),
#                 key='DET.the NOUN.health',
#                 text='the health',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the health,
#                 node=82)
# ic| ent: Entity(loc=(154, 156),
#                 key='NUM.130,000 NOUN.nurse',
#                 text='130,000 nurses',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=130,000 nurses,
#                 node=83)
# ic| ent: Entity(loc=(157, 160),
#                 key='ADJ.other NOUN.health NOUN.worker',
#                 text='other health workers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=other health workers,
#                 node=84)
# ic| ent: Entity(loc=(162, 164),
#                 key='DET.the PROPN.us',
#                 text='the US',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=6,
#                 span=the US,
#                 node=78)
# ic| ent: Entity(loc=(169, 171),
#                 key='NUM.43 NOUN.year',
#                 text='43 years',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=43 years,
#                 node=85)
# ic| ent: Entity(loc=(173, 174),
#                 key='NOUN.datum',
#                 text='data',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=data,
#                 node=33)
# ic| ent: Entity(loc=(175, 177),
#                 key='PRON.their NOUN.diet',
#                 text='their diet',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=7,
#                 span=their diet,
#                 node=86)
# ic| ent: Entity(loc=(184, 186),
#                 key='DET.the NOUN.participant',
#                 text='The participants',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=The participants,
#                 node=87)
# ic| ent: Entity(loc=(192, 195),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(204, 207),
#                 key='ADJ.other NOUN.sandwich NOUN.meat',
#                 text='other sandwich meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=8,
#                 span=other sandwich meat,
#                 node=88)
# ic| ent: Entity(loc=(214, 216),
#                 key='PRON.their NOUN.consumption',
#                 text='their consumption',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=their consumption,
#                 node=89)
# ic| ent: Entity(loc=(217, 218),
#                 key='NOUN.nut',
#                 text='nuts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=nuts,
#                 node=16)
# ic| ent: Entity(loc=(219, 220),
#                 key='NOUN.legume',
#                 text='legumes',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=legumes,
#                 node=41)
# ic| ent: Entity(loc=(228, 230),
#                 key='ADJ.other NOUN.nut',
#                 text='other nuts',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=9,
#                 span=other nuts,
#                 node=90)
# ic| ent: Entity(loc=(244, 248),
#                 key='ADJ.more ADP.than NUM.11,000 NOUN.case',
#                 text='More than 11,000 cases',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=More than 11,000 cases,
#                 node=91)
# ic| ent: Entity(loc=(253, 258),
#                 key='DET.the NOUN.follow PUNCT.- NOUN.up NOUN.period',
#                 text='the follow-up period',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=10,
#                 span=the follow-up period,
#                 node=92)
# ic| ent: Entity(loc=(261, 263),
#                 key='NUM.two NOUN.serving',
#                 text='two servings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=two servings,
#                 node=93)
# ic| ent: Entity(loc=(264, 267),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(272, 274),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=the risk,
#                 node=71)
# ic| ent: Entity(loc=(278, 280),
#                 key='NUM.14 NOUN.%',
#                 text='14%',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=14%,
#                 node=94)
# ic| ent: Entity(loc=(284, 287),
#                 key='ADV.about NUM.three NOUN.serving',
#                 text='about three servings',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=about three servings,
#                 node=95)
# ic| ent: Entity(loc=(290, 292),
#                 key='DET.the NOUN.researcher',
#                 text='the researchers',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=11,
#                 span=the researchers,
#                 node=96)
# ic| ent: Entity(loc=(295, 297),
#                 key='DET.the NOUN.study',
#                 text='The study',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=The study,
#                 node=74)
# ic| ent: Entity(loc=(305, 308),
#                 key='VERB.process ADJ.red NOUN.meat',
#                 text='processed red meat',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=processed red meat,
#                 node=58)
# ic| ent: Entity(loc=(309, 312),
#                 key='DET.a ADJ.daily NOUN.serving',
#                 text='a daily serving',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=a daily serving,
#                 node=97)
# ic| ent: Entity(loc=(322, 324),
#                 key='DET.the NOUN.risk',
#                 text='the risk',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=the risk,
#                 node=71)
# ic| ent: Entity(loc=(327, 329),
#                 key='NUM.23 NOUN.%',
#                 text='23%',
#                 label='NP',
#                 chunk_id=1,
#                 sent_id=12,
#                 span=23%,
#                 node=98)

# %% [markdown]
# Report the relations inferred by `GLiREL`.

# %%
relations: typing.List[dict] = sorted(
    doc._.relations,
    key=lambda x: x["score"],
    reverse=True,
)

for item in relations:
    src_loc: typing.Tuple[int] = tuple(item["head_pos"])
    dst_loc: typing.Tuple[int] = tuple(item["tail_pos"])
    skip_rel: bool = False

    if src_loc not in span_decoder:
        print("MISSING src entity:", item["head_text"], item["head_pos"])

        src_ent: Entity = make_entity(
            doc[item["head_pos"][0] : item["head_pos"][1]],
            chunk,
        )

        if src_ent.key in STOP_WORDS:
            skip_rel = True
        else:
            extract_entity(src_ent)

    if dst_loc not in span_decoder:
        print("MISSING dst entity:", item["tail_text"], item["tail_pos"])

        dst_ent: Entity = make_entity(
            doc[item["tail_pos"][0] : item["tail_pos"][1]],
            chunk,
        )

        if dst_ent.key in STOP_WORDS:
            skip_rel = True
        else:
            extract_entity(dst_ent)

    # link the connected nodes
    if not skip_rel:
        src_ent = span_decoder[src_loc]
        dst_ent = span_decoder[dst_loc]

        rel: str = item["label"].strip().replace(" ", "_").upper()
        prob: float = round(item["score"], 3)

        print(
            f"{src_ent.text} {src_ent.node} -> {rel} -> {dst_ent.text} {dst_ent.node} | {prob}"
        )

        graph.add_edge(
            src_ent.node,
            dst_ent.node,
            rel=rel,
            prob=prob,
        )

# %% [markdown]
# Connect the co-occurring entities.

# %%
ent_map: typing.Dict[int, typing.Set[int]] = defaultdict(set)

for ent in span_decoder.values():
    if ent.node is not None:
        ent_map[ent.sent_id].add(ent.node)

for sent_id, nodes in ent_map.items():
    for pair in itertools.combinations(list(nodes), 2):
        if not graph.has_edge(*pair):
            graph.add_edge(
                pair[0],
                pair[1],
                rel="CO_OCCURS_WITH",
                prob=1.0,
            )

# %% [markdown]
# Run eigenvalue centrality (i.e., _Personalized PageRank_) to rank the entities.

# %%
for node, rank in nx.pagerank(graph, alpha=TR_ALPHA, weight="count").items():
    graph.nodes[node]["rank"] = rank

# %% [markdown]
# Report the top-ranked entities extracted from this text chunk.

# %%
df: pd.DataFrame = pd.DataFrame(
    [
        node_attr
        for node, node_attr in graph.nodes(data=True)
        if node_attr["kind"] == "Entity"
    ]
).sort_values(by=["rank", "count"], ascending=False)

df.head(20)
# Out:
#                                key    kind    pos                text  chunk  \
# 1                    NOUN.dementia  Entity   NOUN            dementia      1
# 21  VERB.process ADJ.red NOUN.meat  Entity     NP  processed red meat      1
# 5                         PROPN.us  Entity  PROPN                  US      1
# 8                        NOUN.bean  Entity   NOUN               beans      1
# 7                         NOUN.nut  Entity   NOUN                nuts      1
# 2                       NOUN.study  Entity   NOUN               study      1
# 0                        NOUN.risk  Entity   NOUN                risk      1
# 9                        NOUN.tofu  Entity   NOUN                tofu      1
# 26               ADJ.red NOUN.meat  Entity     NP            red meat      1
# 34               DET.the NOUN.risk  Entity     NP            the risk      1
# 6                  NOUN.researcher  Entity   NOUN         researchers      1
# 10                       NOUN.diet  Entity   NOUN                diet      1
# 25      ADJ.cognitive NOUN.decline  Entity     NP   cognitive decline      1
# 18                     NOUN.peanut  Entity   NOUN              peanut      1
# 3                      NOUN.people  Entity   NOUN              people      1
# 20                        NOUN.pea  Entity   NOUN                peas      1
# 11                     NOUN.expert  Entity   NOUN             experts      1
# 41                DET.the PROPN.us  Entity     NP              the US      1
# 17                     NOUN.legume  Entity   NOUN             legumes      1
# 29              NOUN.soy NOUN.milk  Entity     NP            soy milk      1
#
#     count         label      rank
# 1      12     Condition  0.037842
# 21      6          Food  0.026846
# 5       6       Country  0.024923
# 8       7          Food  0.023906
# 7       8          Food  0.023219
# 2       6      Research  0.022295
# 0       7            NP  0.022273
# 9       6          Food  0.021581
# 26      3          Food  0.019168
# 34      4            NP  0.017751
# 6       4  People Group  0.017068
# 10      3            NP  0.014910
# 25      2     Condition  0.014830
# 18      3          Food  0.012902
# 3       3            NP  0.012274
# 20      2          Food  0.012147
# 11      2            NP  0.012083
# 41      2            NP  0.012072
# 17      2            NP  0.011332
# 29      1          Food  0.011315

# %% [markdown]
# ## Visualize the results

# %% [markdown]
# Use `pyvis` to provide an interactive visualization of both layers of the graph, so far...

# %%
pv_net: pyvis.network.Network = pyvis.network.Network(
    height="750px",
    width="100%",
    notebook=True,
    cdn_resources="remote",
)

for node_id, node_attr in graph.nodes(data=True):
    if node_attr["kind"] == "Entity":
        color: str = "hsl(65, 46%, 58%)"
        size: int = round(200 * node_attr["rank"])
    else:
        color = "hsla(72, 10%, 90%, 0.95)"
        size = round(30 * node_attr["rank"])

    pv_net.add_node(
        node_id,
        label=node_attr["text"],
        title=node_attr.get("label"),
        color=color,
        size=size,
    )

for src_node, dst_node, edge_attr in graph.edges(data=True):
    pv_net.add_edge(
        src_node,
        dst_node,
        title=edge_attr.get("rel"),
    )

pv_net.toggle_physics(True)
pv_net.show("chunk.html")
# Out:
# chunk.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="chunk.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Show a cluster analysis of the _lexical graph_.

# %%
communities: typing.Generator = nx.community.louvain_communities(graph)

comm_map: typing.Dict[int, int] = {
    node_id: i for i, comm in enumerate(communities) for node_id in comm
}

xkcd_colors: typing.List[str] = list(matplotlib.colors.XKCD_COLORS.values())

colors: typing.List[str] = [xkcd_colors[comm_map[n]] for n in list(graph.nodes())]

labels: typing.Dict[int, str] = {
    node_id: node_attr["text"] for node_id, node_attr in graph.nodes(data=True)
}

# %%
SPRING_DISTANCE: float = 2.5

nx.draw_networkx(
    graph,
    pos=nx.spring_layout(
        graph,
        k=SPRING_DISTANCE / len(communities),
    ),
    labels=labels,
    node_color=colors,
    edge_color="#bbb",
    with_labels=True,
    font_size=8,
)

# %% [markdown]
# ## Tear down

# %% [markdown]
# How much did the global data structures grow?

# %%
ic(len(known_lemma))
ic(len(span_decoder))
ic(len(graph.nodes()))
# Out:
# ic| len(known_lemma): 99
# ic| len(span_decoder): 96
# ic| len(graph.nodes()): 99
# 99

# %% [markdown]
# Stop the profiler and report the performance measures.

# %%
profiler.stop()
profiler.print()
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 23:02:09  Samples:  36609
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 1399.884  CPU time: 49.544
# /   _/                      v5.0.1
#
# Profile at /var/folders/xx/bd1n9dh91yl75wqwj1g3nm8m0000gn/T/ipykernel_80855/382364451.py:2
#
# 1399.880 _UnixSelectorEventLoop._run_once  asyncio/base_events.py:1915
# ├─ 1272.256 KqueueSelector.select  selectors.py:558
# │  └─ 1272.253 kqueue.control  <built-in>
# └─ 127.623 Handle._run  asyncio/events.py:86
#       [11 frames hidden]  ipykernel, IPython
#          127.017 ZMQInteractiveShell.run_ast_nodes  IPython/core/interactiveshell.py:3420
#          └─ 115.851 <module>  ../ipykernel_80855/247616181.py:1
#             └─ 115.173 English.add_pipe  spacy/language.py:767
#                   [61 frames hidden]  spacy, confection, glirel, huggingfac...

# %% [markdown]
# ## Quality checks

# %% [markdown]
# Are there any prounoun lemmas that we need to add to the `STOP_WORDS` list? Until we have a good _coreference_ stage in this workflow, the pronouns are too generic and tend to distort the graph results. NB: compound references are "contained" and not a problem.

# %%
for x in known_lemma:
    if "PRON" in x:
        print(x)
# Out:
# PRON.their NOUN.diet
# PRON.their NOUN.consumption

# %% [markdown]
# Which nodes should we promote to the next level?

# %%
kept_nodes: typing.Set[int] = set()

for node_id, node_attr in graph.nodes(data=True):
    if node_attr["kind"] == "Entity":
        print(
            node_id,
            node_attr["key"],
            node_attr["rank"],
            node_attr["label"],
            node_attr["text"],
            node_attr["chunk"],
        )
        kept_nodes.add(node_id)
# Out:
# 1 NOUN.risk 0.022273445844157014 NP risk 1
# 3 NOUN.dementia 0.03784166316954037 Condition dementia 1
# 4 NOUN.study 0.02229484466199892 Research study 1
# 5 NOUN.people 0.012274218272678633 NP people 1
# 7 NOUN.cancer 0.009973370015756003 Condition cancer 1
# 12 PROPN.us 0.02492329716584656 Country US 1
# 13 NOUN.researcher 0.01706818283821244 People Group researchers 1
# 16 NOUN.nut 0.023218751670599603 Food nuts 1
# 17 NOUN.bean 0.023905882300761638 Food beans 1
# 18 NOUN.tofu 0.021581423001160435 Food tofu 1
# 24 NOUN.diet 0.014910001675728073 NP diet 1
# 28 NOUN.expert 0.012082506905866753 NP experts 1
# 33 NOUN.datum 0.007574845334096963 NP data 1
# 35 NOUN.bacon 0.009197546265640623 Food bacon 1
# 36 NOUN.hotdog 0.010179737953615308 Food hotdogs 1
# 37 NOUN.sausage 0.009134814405229206 Food sausages 1
# 38 NOUN.salami 0.009134814405229206 Food salami 1
# 41 NOUN.legume 0.011331612399829081 NP legumes 1
# 42 NOUN.peanut 0.01290178057186229 Food peanut 1
# 44 NOUN.walnut 0.01122625135220749 Food walnuts 1
# 46 NOUN.pea 0.012146815328917912 Food peas 1
# 58 VERB.process ADJ.red NOUN.meat 0.026845800644584857 Food processed red meat 1
# 59 NOUN.heart NOUN.disease 0.007153083104791251 Condition heart disease 1
# 60 NOUN.type NUM.2 NOUN.diabetes 0.007402466708975144 Condition type 2 diabetes 1
# 61 PROPN.alzheimer PART.’s PROPN.association ADJ.international NOUN.conference 0.010018562815948644 Conference Alzheimer’s Association international conference 1
# 62 ADJ.cognitive NOUN.decline 0.014829635971137988 Condition cognitive decline 1
# 63 ADJ.red NOUN.meat 0.019168085487519203 Food red meat 1
# 64 NOUN.peanut NOUN.butter 0.010394587209836766 Food peanut butter 1
# 65 NOUN.string NOUN.bean 0.010349834948585239 Food string beans 1
# 66 NOUN.soy NOUN.milk 0.011315064367291756 Food soy milk 1
# 67 DET.a ADJ.significant NOUN.risk NOUN.factor 0.007776484592611848 NP a significant risk factor 1
# 68 DET.a ADJ.large NOUN.study 0.006803582970151351 NP a large study 1
# 69 ADJ.more ADP.than NUM.100,000 NOUN.people 0.0069011907325734105 NP more than 100,000 people 1
# 70 NUM.four NOUN.decade 0.007068525090445642 NP four decades 1
# 71 DET.the NOUN.risk 0.017751268156619076 NP the risk 1
# 72 PROPN.us NOUN.researcher 0.005498162526582294 NP US researchers 1
# 73 DET.a ADJ.potential NOUN.link 0.0057579487677826375 NP a potential link 1
# 74 DET.the NOUN.study 0.009811047362815207 NP The study 1
# 75 ADJ.healthy NOUN.food 0.007592622052250156 NP healthier foods 1
# 76 DET.the NOUN.finding 0.007551577628384589 NP The findings 1
# 77 DET.the PROPN.alzheimer PART.’s PROPN.association ADJ.international NOUN.conference 0.010018562815948644 NP the Alzheimer’s Association international conference 1
# 78 DET.the PROPN.us 0.012072060487471436 NP the US 1
# 79 DET.the NOUN.number 0.00930422493257866 NP The number 1
# 80 DET.a NOUN.focus 0.009270171594687874 NP a focus 1
# 81 DET.the ADJ.late NOUN.research 0.009647805548069426 NP the latest research 1
# 82 DET.the NOUN.health 0.00951401405824826 NP the health 1
# 83 NUM.130,000 NOUN.nurse 0.009563208077519323 NP 130,000 nurses 1
# 84 ADJ.other NOUN.health NOUN.worker 0.010822036081502673 NP other health workers 1
# 85 NUM.43 NOUN.year 0.006396967468575681 NP 43 years 1
# 86 PRON.their NOUN.diet 0.005913077019914628 NP their diet 1
# 87 DET.the NOUN.participant 0.00838562810002395 NP The participants 1
# 88 ADJ.other NOUN.sandwich NOUN.meat 0.009134814405229206 NP other sandwich meat 1
# 89 PRON.their NOUN.consumption 0.010454659918539859 NP their consumption 1
# 90 ADJ.other NOUN.nut 0.009518056872887593 NP other nuts 1
# 91 ADJ.more ADP.than NUM.11,000 NOUN.case 0.00503701225789661 NP More than 11,000 cases 1
# 92 DET.the NOUN.follow PUNCT.- NOUN.up NOUN.period 0.007736244717581394 NP the follow-up period 1
# 93 NUM.two NOUN.serving 0.007864832574355326 NP two servings 1
# 94 NUM.14 NOUN.% 0.007930756239074207 NP 14% 1
# 95 ADV.about NUM.three NOUN.serving 0.007864832574355326 NP about three servings 1
# 96 DET.the NOUN.researcher 0.007925790875043038 NP the researchers 1
# 97 DET.a ADJ.daily NOUN.serving 0.009791876714923995 NP a daily serving 1
# 98 NUM.23 NOUN.% 0.009859574284022198 NP 23% 1

# %% [markdown]
# Which edges should we promote to the next level?

# %%
skip_rel: typing.Set[str] = set(["FOLLOWS_LEXICALLY", "COMPOUND_ELEMENT_OF"])

for src_id, dst_id, edge_attr in graph.edges(data=True):
    if src_id in kept_nodes and dst_id in kept_nodes:
        rel: str = edge_attr["rel"]

        if rel not in skip_rel:
            print(src_id, dst_id, rel, edge_attr["prob"])
# Out:
# 1 5 CO_OCCURS_WITH 1.0
# 1 79 CO_OCCURS_WITH 1.0
# 1 80 CO_OCCURS_WITH 1.0
# 1 62 CO_OCCURS_WITH 1.0
# 3 67 CO_OCCURS_WITH 1.0
# 3 68 CO_OCCURS_WITH 1.0
# 3 69 CO_OCCURS_WITH 1.0
# 3 70 CO_OCCURS_WITH 1.0
# 3 58 CO_OCCURS_WITH 1.0
# 3 72 CO_OCCURS_WITH 1.0
# 3 73 CO_OCCURS_WITH 1.0
# 3 71 CO_OCCURS_WITH 1.0
# 3 74 CO_OCCURS_WITH 1.0
# 3 75 CO_OCCURS_WITH 1.0
# 3 16 CO_OCCURS_WITH 1.0
# 3 79 CO_OCCURS_WITH 1.0
# 3 80 CO_OCCURS_WITH 1.0
# 3 62 CO_OCCURS_WITH 1.0
# 3 91 CO_OCCURS_WITH 1.0
# 3 92 CO_OCCURS_WITH 1.0
# 3 97 CO_OCCURS_WITH 1.0
# 3 98 CO_OCCURS_WITH 1.0
# 3 63 CO_OCCURS_WITH 1.0
# 4 13 CO_OCCURS_WITH 1.0
# 4 79 CO_OCCURS_WITH 1.0
# 4 80 CO_OCCURS_WITH 1.0
# 4 62 CO_OCCURS_WITH 1.0
# 4 97 CO_OCCURS_WITH 1.0
# 4 98 CO_OCCURS_WITH 1.0
# 4 71 CO_OCCURS_WITH 1.0
# 4 17 CO_OCCURS_WITH 1.0
# 4 18 CO_OCCURS_WITH 1.0
# 4 58 CO_OCCURS_WITH 1.0
# 4 63 CO_OCCURS_WITH 1.0
# 5 13 CO_OCCURS_WITH 1.0
# 5 79 CO_OCCURS_WITH 1.0
# 5 80 CO_OCCURS_WITH 1.0
# 5 62 CO_OCCURS_WITH 1.0
# 7 71 CO_OCCURS_WITH 1.0
# 7 58 CO_OCCURS_WITH 1.0
# 7 59 CO_OCCURS_WITH 1.0
# 7 60 CO_OCCURS_WITH 1.0
# 12 73 CO_OCCURS_WITH 1.0
# 12 77 CO_OCCURS_WITH 1.0
# 12 76 CO_OCCURS_WITH 1.0
# 12 61 CO_OCCURS_WITH 1.0
# 12 81 CO_OCCURS_WITH 1.0
# 12 82 CO_OCCURS_WITH 1.0
# 12 83 CO_OCCURS_WITH 1.0
# 12 84 CO_OCCURS_WITH 1.0
# 12 28 CO_OCCURS_WITH 1.0
# 13 79 CO_OCCURS_WITH 1.0
# 13 80 CO_OCCURS_WITH 1.0
# 13 24 CO_OCCURS_WITH 1.0
# 13 62 CO_OCCURS_WITH 1.0
# 16 71 CO_OCCURS_WITH 1.0
# 16 74 CO_OCCURS_WITH 1.0
# 16 75 CO_OCCURS_WITH 1.0
# 16 58 CO_OCCURS_WITH 1.0
# 16 64 CO_OCCURS_WITH 1.0
# 16 65 CO_OCCURS_WITH 1.0
# 16 66 CO_OCCURS_WITH 1.0
# 16 46 CO_OCCURS_WITH 1.0
# 16 89 CO_OCCURS_WITH 1.0
# 16 97 CO_OCCURS_WITH 1.0
# 16 98 CO_OCCURS_WITH 1.0
# 16 63 CO_OCCURS_WITH 1.0
# 17 71 CO_OCCURS_WITH 1.0
# 17 74 CO_OCCURS_WITH 1.0
# 17 75 CO_OCCURS_WITH 1.0
# 17 58 CO_OCCURS_WITH 1.0
# 17 64 CO_OCCURS_WITH 1.0
# 17 66 CO_OCCURS_WITH 1.0
# 17 41 CO_OCCURS_WITH 1.0
# 17 42 CO_OCCURS_WITH 1.0
# 17 89 CO_OCCURS_WITH 1.0
# 17 90 CO_OCCURS_WITH 1.0
# 17 97 CO_OCCURS_WITH 1.0
# 17 98 CO_OCCURS_WITH 1.0
# 17 63 CO_OCCURS_WITH 1.0
# 18 71 CO_OCCURS_WITH 1.0
# 18 74 CO_OCCURS_WITH 1.0
# 18 75 CO_OCCURS_WITH 1.0
# 18 58 CO_OCCURS_WITH 1.0
# 18 64 CO_OCCURS_WITH 1.0
# 18 65 CO_OCCURS_WITH 1.0
# 18 66 CO_OCCURS_WITH 1.0
# 18 41 CO_OCCURS_WITH 1.0
# 18 42 CO_OCCURS_WITH 1.0
# 18 44 CO_OCCURS_WITH 1.0
# 18 89 CO_OCCURS_WITH 1.0
# 18 90 CO_OCCURS_WITH 1.0
# 18 97 CO_OCCURS_WITH 1.0
# 18 98 CO_OCCURS_WITH 1.0
# 18 63 CO_OCCURS_WITH 1.0
# 24 79 CO_OCCURS_WITH 1.0
# 24 80 CO_OCCURS_WITH 1.0
# 24 62 CO_OCCURS_WITH 1.0
# 28 78 CO_OCCURS_WITH 1.0
# 28 81 CO_OCCURS_WITH 1.0
# 28 82 CO_OCCURS_WITH 1.0
# 28 83 CO_OCCURS_WITH 1.0
# 28 84 CO_OCCURS_WITH 1.0
# 33 85 CO_OCCURS_WITH 1.0
# 33 86 CO_OCCURS_WITH 1.0
# 35 87 CO_OCCURS_WITH 1.0
# 35 88 CO_OCCURS_WITH 1.0
# 35 58 CO_OCCURS_WITH 1.0
# 35 63 CO_OCCURS_WITH 1.0
# 36 87 CO_OCCURS_WITH 1.0
# 36 88 CO_OCCURS_WITH 1.0
# 36 58 CO_OCCURS_WITH 1.0
# 36 63 CO_OCCURS_WITH 1.0
# 37 87 CO_OCCURS_WITH 1.0
# 37 88 CO_OCCURS_WITH 1.0
# 37 58 CO_OCCURS_WITH 1.0
# 37 63 CO_OCCURS_WITH 1.0
# 38 87 CO_OCCURS_WITH 1.0
# 38 88 CO_OCCURS_WITH 1.0
# 38 58 CO_OCCURS_WITH 1.0
# 38 63 CO_OCCURS_WITH 1.0
# 41 64 CO_OCCURS_WITH 1.0
# 41 65 CO_OCCURS_WITH 1.0
# 41 66 CO_OCCURS_WITH 1.0
# 41 44 CO_OCCURS_WITH 1.0
# 41 46 CO_OCCURS_WITH 1.0
# 41 89 CO_OCCURS_WITH 1.0
# 41 90 CO_OCCURS_WITH 1.0
# 42 65 CO_OCCURS_WITH 1.0
# 42 66 CO_OCCURS_WITH 1.0
# 42 46 CO_OCCURS_WITH 1.0
# 42 89 CO_OCCURS_WITH 1.0
# 42 90 CO_OCCURS_WITH 1.0
# 44 64 CO_OCCURS_WITH 1.0
# 44 65 CO_OCCURS_WITH 1.0
# 44 66 CO_OCCURS_WITH 1.0
# 44 46 CO_OCCURS_WITH 1.0
# 44 89 CO_OCCURS_WITH 1.0
# 44 90 CO_OCCURS_WITH 1.0
# 46 64 CO_OCCURS_WITH 1.0
# 46 65 CO_OCCURS_WITH 1.0
# 46 66 CO_OCCURS_WITH 1.0
# 46 89 CO_OCCURS_WITH 1.0
# 46 90 CO_OCCURS_WITH 1.0
# 58 67 CO_OCCURS_WITH 1.0
# 58 68 CO_OCCURS_WITH 1.0
# 58 69 CO_OCCURS_WITH 1.0
# 58 70 CO_OCCURS_WITH 1.0
# 58 71 CO_OCCURS_WITH 1.0
# 58 59 CO_OCCURS_WITH 1.0
# 58 60 CO_OCCURS_WITH 1.0
# 58 74 CO_OCCURS_WITH 1.0
# 58 75 CO_OCCURS_WITH 1.0
# 58 87 CO_OCCURS_WITH 1.0
# 58 88 CO_OCCURS_WITH 1.0
# 58 63 CO_OCCURS_WITH 1.0
# 58 96 CO_OCCURS_WITH 1.0
# 58 95 CO_OCCURS_WITH 1.0
# 58 94 CO_OCCURS_WITH 1.0
# 58 93 CO_OCCURS_WITH 1.0
# 58 62 CO_OCCURS_WITH 1.0
# 58 97 CO_OCCURS_WITH 1.0
# 58 98 CO_OCCURS_WITH 1.0
# 59 71 CO_OCCURS_WITH 1.0
# 59 60 CO_OCCURS_WITH 1.0
# 60 71 CO_OCCURS_WITH 1.0
# 61 77 CO_OCCURS_WITH 1.0
# 61 78 CO_OCCURS_WITH 1.0
# 61 76 CO_OCCURS_WITH 1.0
# 62 79 CO_OCCURS_WITH 1.0
# 62 80 CO_OCCURS_WITH 1.0
# 62 96 CO_OCCURS_WITH 1.0
# 62 71 CO_OCCURS_WITH 1.0
# 62 95 CO_OCCURS_WITH 1.0
# 62 94 CO_OCCURS_WITH 1.0
# 62 93 CO_OCCURS_WITH 1.0
# 62 63 CO_OCCURS_WITH 1.0
# 63 87 CO_OCCURS_WITH 1.0
# 63 88 CO_OCCURS_WITH 1.0
# 63 96 CO_OCCURS_WITH 1.0
# 63 71 CO_OCCURS_WITH 1.0
# 63 95 CO_OCCURS_WITH 1.0
# 63 94 CO_OCCURS_WITH 1.0
# 63 93 CO_OCCURS_WITH 1.0
# 63 97 CO_OCCURS_WITH 1.0
# 63 98 CO_OCCURS_WITH 1.0
# 63 74 CO_OCCURS_WITH 1.0
# 64 65 CO_OCCURS_WITH 1.0
# 64 66 CO_OCCURS_WITH 1.0
# 64 89 CO_OCCURS_WITH 1.0
# 64 90 CO_OCCURS_WITH 1.0
# 65 66 CO_OCCURS_WITH 1.0
# 65 89 CO_OCCURS_WITH 1.0
# 65 90 CO_OCCURS_WITH 1.0
# 66 89 CO_OCCURS_WITH 1.0
# 66 90 CO_OCCURS_WITH 1.0
# 67 68 CO_OCCURS_WITH 1.0
# 67 69 CO_OCCURS_WITH 1.0
# 67 70 CO_OCCURS_WITH 1.0
# 68 69 CO_OCCURS_WITH 1.0
# 68 70 CO_OCCURS_WITH 1.0
# 69 70 CO_OCCURS_WITH 1.0
# 71 74 CO_OCCURS_WITH 1.0
# 71 75 CO_OCCURS_WITH 1.0
# 71 96 CO_OCCURS_WITH 1.0
# 71 95 CO_OCCURS_WITH 1.0
# 71 94 CO_OCCURS_WITH 1.0
# 71 93 CO_OCCURS_WITH 1.0
# 71 97 CO_OCCURS_WITH 1.0
# 71 98 CO_OCCURS_WITH 1.0
# 72 73 CO_OCCURS_WITH 1.0
# 74 75 CO_OCCURS_WITH 1.0
# 74 97 CO_OCCURS_WITH 1.0
# 74 98 CO_OCCURS_WITH 1.0
# 76 77 CO_OCCURS_WITH 1.0
# 76 78 CO_OCCURS_WITH 1.0
# 77 78 CO_OCCURS_WITH 1.0
# 78 81 CO_OCCURS_WITH 1.0
# 78 82 CO_OCCURS_WITH 1.0
# 78 83 CO_OCCURS_WITH 1.0
# 78 84 CO_OCCURS_WITH 1.0
# 79 80 CO_OCCURS_WITH 1.0
# 81 82 CO_OCCURS_WITH 1.0
# 81 83 CO_OCCURS_WITH 1.0
# 81 84 CO_OCCURS_WITH 1.0
# 82 83 CO_OCCURS_WITH 1.0
# 82 84 CO_OCCURS_WITH 1.0
# 83 84 CO_OCCURS_WITH 1.0
# 85 86 CO_OCCURS_WITH 1.0
# 87 88 CO_OCCURS_WITH 1.0
# 89 90 CO_OCCURS_WITH 1.0
# 91 92 CO_OCCURS_WITH 1.0
# 93 96 CO_OCCURS_WITH 1.0
# 93 95 CO_OCCURS_WITH 1.0
# 93 94 CO_OCCURS_WITH 1.0
# 94 96 CO_OCCURS_WITH 1.0
# 94 95 CO_OCCURS_WITH 1.0
# 95 96 CO_OCCURS_WITH 1.0
# 97 98 CO_OCCURS_WITH 1.0
